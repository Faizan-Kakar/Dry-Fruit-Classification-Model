# %% [markdown]
# <a href="https://colab.research.google.com/github/Faizan-Kakar/colab/blob/main/DryFruitDetection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Liabraries Imports
import keras
from keras.models import Sequential, load_model
from keras.layers import Dense , Input, GlobalAveragePooling2D
from keras.optimizers import Adam
from keras.applications import EfficientNetB0 , VGG16
import numpy as np
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay
import matplotlib.pyplot as plt
from tensorflow.keras.preprocessing.image import ImageDataGenerator

from keras.models import Model
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing import image

# %%
# Model Creation
base_model = VGG16(weights='imagenet')
model = Model(inputs=base_model.input , outputs=base_model.layers[-2].output)
sequentialModel = Sequential()
for layers in model.layers:
  sequentialModel.add(layers)

for layer in sequentialModel.layers:
  layer.trainable=False

sequentialModel.add(Dense(7, activation='softmax', name='Prediction'))
sequentialModel.summary()
# Out:
# ...
# 553467096/553467096 ━━━━━━━━━━━━━━━━━━━━ 6s 0us/step
# Model: "sequential_3"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ block1_conv1 (Conv2D)                │ (None, 224, 224, 64)        │           1,792 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_conv2 (Conv2D)                │ (None, 224, 224, 64)        │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block1_pool (MaxPooling2D)           │ (None, 112, 112, 64)        │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ block2_conv1 (Conv2D)                │ (None, 112, 112, 128)       │          73,856 │
# ...

# %%
# Loading and preprocesiing the data For training
train_direc = "/content/drive/My Drive/Datasets/dryFruitDataset/train"
test_direc = "/content/drive/My Drive/Datasets/dryFruitDataset/test"

train_datagen = ImageDataGenerator(validation_split=0.2)
train_batches = train_datagen.flow_from_directory(train_direc,
                                                  batch_size=32,
                                                  target_size=(244,244),
                                                  class_mode='categorical')
test_batches = ImageDataGenerator().flow_from_directory(test_direc , batch_size=6, target_size=(244,244))
# Out:
# Found 3573 images belonging to 7 classes.
# Found 72 images belonging to 7 classes.

# %%
# Model Training and Compiling
sequentialModel.compile(optimizer=Adam(learning_rate=0.0001), loss='categorical_crossentropy', metrics=['accuracy'])
sequentialModel.fit(train_batches, epochs=10, verbose=2)
# Out:
# Epoch 1/10
# 112/112 - 1034s - 9s/step - accuracy: 0.7881 - loss: 0.6399
# Epoch 2/10
# 112/112 - 60s - 537ms/step - accuracy: 0.9457 - loss: 0.2039
# Epoch 3/10
# 112/112 - 70s - 622ms/step - accuracy: 0.9784 - loss: 0.1170
# Epoch 4/10
# 112/112 - 62s - 551ms/step - accuracy: 0.9891 - loss: 0.0786
# Epoch 5/10
# 112/112 - 64s - 568ms/step - accuracy: 0.9941 - loss: 0.0572
# Epoch 6/10
# 112/112 - 61s - 542ms/step - accuracy: 0.9975 - loss: 0.0439
# Epoch 7/10
# 112/112 - 62s - 554ms/step - accuracy: 0.9983 - loss: 0.0347
# Epoch 8/10
# 112/112 - 60s - 537ms/step - accuracy: 0.9983 - loss: 0.0285
# Epoch 9/10
# 112/112 - 61s - 543ms/step - accuracy: 0.9992 - loss: 0.0241
# Epoch 10/10
# 112/112 - 63s - 563ms/step - accuracy: 0.9992 - loss: 0.0201

# %%
model = load_model('/content/drive/My Drive/Datasets/dryFruitDataset/fruitModel7Categories.keras')

# %%
imgs , test_labels = next(test_batches)
encoded_test_labels = np.argmax(test_labels , axis=1)

pred=model.predict(imgs)
categorical_pred = np.argmax(pred, axis=1)
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 6s 6s/step

# %%
print(encoded_test_labels)
print(categorical_pred)
# Out:
# [0 6 1 3 3 2]
# [1 6 6 3 3 2]

# %%
class_labels = ["Almond", "Cashew", "Fig", "Peanut", "Pistachio", "Raisin", "Walnut"]

img_path = "/content/almond.webp"  # Replace with your image path
img = image.load_img(img_path, target_size=(244, 244))  # Resize image

# Convert image to numpy array and preprocess
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension

# Predict using the trained model
predictions = model.predict(img_array)  # Get probability output
predicted_index = np.argmax(predictions)  # Get index of highest probability

print(predicted_index)
# Print detected fruit
predicted_fruit = class_labels[predicted_index]
print(f"Predicted Dry Fruit: {predicted_fruit}")

# Print result
# print(f"Predicted Class: {predicted_label} ({predictions[0][predicted_index]:.2f} confidence)")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 1s 786ms/step
# 0
# Predicted Dry Fruit: Almond
